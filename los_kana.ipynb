# %% [markdown]
# <a href="https://colab.research.google.com/github/brchung2/TPC-LoS-prediction/blob/master/los_kana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MIC-DKFZ/trixi.git
# %cd trixi
# !pip install -e .
# Out:
# Cloning into 'trixi'...
# remote: Enumerating objects: 4553, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 4553 (delta 85), reused 78 (delta 17), pack-reused 4407
# Receiving objects: 100% (4553/4553), 15.83 MiB | 10.22 MiB/s, done.
# Resolving deltas: 100% (2941/2941), done.
# /content/trixi
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/trixi
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.8/535.8 kB 54.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !captum --version
# Out:
# /bin/bash: captum: command not found

# %%
# %cd /content
# !pwd
# Out:
# /content
# /content

# %%
# !git clone https://github.com/brchung2/TPC-LoS-prediction.git
# Out:
# Cloning into 'TPC-LoS-prediction'...
# remote: Enumerating objects: 1286, done.
# remote: Counting objects: 100% (1286/1286), done.
# remote: Compressing objects: 100% (305/305), done.
# remote: Total 1286 (delta 974), reused 1270 (delta 967), pack-reused 0
# Receiving objects: 100% (1286/1286), 3.34 MiB | 23.28 MiB/s, done.
# Resolving deltas: 100% (974/974), done.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 759 bytes | 759.00 KiB/s, done.
# From https://github.com/brchung2/TPC-LoS-prediction
#    ea511ca..265ed8e  master     -> origin/master
# Updating ea511ca..265ed8e
# Fast-forward
#  models/run_tpc.py | 2 ++
#  1 file changed, 2 insertions(+)

# %%
!

# %%
# %cd /content/TPC-LoS-prediction
# Out:
# /content/TPC-LoS-prediction

# %%
# !pwd
# Out:
# /content/TPC-LoS-prediction

# %%
/content/drive/MyDrive/
/content/drive/MyDrive/eICU_data

# %%
# !python3 -m models.run_tpc --dataset eICU --task LoS --percentage_data 0.005
# Out:
# 2023-04-30 21:32:25.998877: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 21:32:27.028076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
# ...

# %%
# !python3 -m models.run_tpc --dataset eICU --task LoS --percentage_data 5
# Out:
# 2023-04-30 21:54:08.498342: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 21:54:10.434944: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 32,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 64,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 4,
#     "labs_only": false,
#     "last_linear_size": 17,
#     "learning_rate": 0.00226,
#     "loss": "msle",
#     "main_dropout_rate": 0.45,
#     "mode": "train",
# ...

# %%
# !python3 -m models.run_tpc --dataset eICU --task LoS --model_type tpc --percentage_data 0.005
# Out:
# 2023-04-30 21:29:32.097397: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 21:29:33.135873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# usage: run_tpc.py
#        [-h]
#        [--dataset DATASET]
#        [-disable_cuda]
#        [-intermediate_reporting]
#        [--batch_size_test BATCH_SIZE_TEST]
#        [-shuffle_train]
#        [-save_results_csv]
#        [--percentage_data PERCENTAGE_DATA]
#        [--task TASK]
#        [--mode MODE]
#        [--loss LOSS]
#        [-sum_losses]
#        [-labs_only]
#        [-no_mask]
#        [-no_diag]
#        [-no_labs]
#        [-no_exp]
#        [--alpha ALPHA]
#        [--main_dropout_rate MAIN_DROPOUT_RATE]
# ...
